# %% [markdown]
# # Cross-Modal Diagnostic Observability — Stage T2-KR v0.4
#
# CPU continuation with frozen source-axis schema adaptation. Use **Runtime → Disconnect and delete runtime**, select **CPU**, then **Run all**.

# %%
from google.colab import drive
drive.mount('/content/drive')
from pathlib import Path
import base64, zlib
payload_path = Path('/content/drive/MyDrive/Cross-Modal_Diagnostic_Observability/05_Code/Cross_Modal/StageT2KR_CPU_pipeline_v0.4.b85')
payload = payload_path.read_text(encoding='utf-8-sig').strip()
source = zlib.decompress(base64.b85decode(payload)).decode('utf-8')
exec(compile(source, 'StageT2KR_CPU_pipeline_v0.4.py', 'exec'))
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# HiSBreast archive confirmed: HiSBreast_Version 2.zip 1023775322 bytes
# Stage T2-KR protocol: 69a29a280f62f30d9665b0cc1bca7ad564dc25c597a3896172db365e44bacfa4
# Locked blind assets touched: False
# HiSBreast images / diagnosis files / JSON containers / expanded JSON records / annotation rows: 972 1944 16 3052 972
#   top_release_folder suffix  files       bytes
# 0          HiSBreast   .csv      1      185693
# 1          HiSBreast  .json     16  1018751576
# 2          HiSBreast   .png    972   250721155
# 3          HiSBreast   .txt   1944      181735
# 4           __MACOSX             5        1035
# 5           __MACOSX   .csv      1         178
# 6           __MACOSX  .json     16        2992
# 7           __MACOSX   .png    972      181764
# 8           __MACOSX   .txt   1944      363528
# ...
