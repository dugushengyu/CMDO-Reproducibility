# %% [markdown]
# # Cross-Modal Diagnostic Observability — Stage T2-L
#
# Independent target acquisition, harmonisation, frozen source scoring and evidence/model-limited regime expansion. Use a clean **CPU** runtime and select **Runtime → Run all**. Automatic downloads and CPU embeddings may take 1–4 hours.

# %%
from google.colab import drive
drive.mount('/content/drive')
from pathlib import Path
import base64, zlib
payload_path = Path('/content/drive/MyDrive/Cross-Modal_Diagnostic_Observability/05_Code/Cross_Modal/StageT2L_pipeline_v0.1.b85')
payload = payload_path.read_text(encoding='utf-8-sig').strip()
source = zlib.decompress(base64.b85decode(payload)).decode('utf-8')
exec(compile(source, 'StageT2L_pipeline_v0.1.py', 'exec'))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Stage T2-L protocol: 5211140a651b5ddd4d6b337c0926ef9236963198b363316323899df63c19e7c0
# Single-pilot deployment authorised: False
# Locked blind assets touched: False
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: isic-archive.s3.amazonaws.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: isic-archive.s3.amazonaws.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: isic-archive.s3.amazonaws.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: isic-archive.s3.amazonaws.com. Connection pool size: 10
# ...
